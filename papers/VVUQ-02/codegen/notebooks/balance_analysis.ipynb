# %% [markdown]
# # Balance Analysis
#
# Exercises the ZMP margin and the posture controller (VVUQ 03) under a surgical reaction force.

# %%
from src.balance.zmp import zmp_margin
from src.balance.posture_controller import stabilize

print('rest margin mm', zmp_margin((0.0, 0.0), 0.78, (0.0, 0.0)))
cmd = stabilize((0.0, 0.0), (300.0, 0.0))
print('large push -> scale', cmd.admitted_force_scale, 'state', cmd.balance_state)
