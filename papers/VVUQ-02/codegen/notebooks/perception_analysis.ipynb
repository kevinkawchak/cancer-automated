# %% [markdown]
# # Perception Analysis
#
# Shows how the mean Dice agreement (VVUQ 08) degrades with the occlusion fraction.

# %%
from src.perception.segment import reference_masks, segment, mean_dice

ref = reference_masks()
for occ in (0.0, 0.1, 0.3):
    print('occlusion', occ, 'mean dice', round(mean_dice(segment(occlusion_fraction=occ), ref), 4))
